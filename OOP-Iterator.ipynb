# %% [markdown]
# Create an Iterator from a list and print it's first two elements using next()?

# %%
madhurima=[1,2,3,4,5,6,7,8,9]
iterator=iter(madhurima)

# %%
print(next(iterator))
print(next(iterator))
# Out:
# 1
# 2

# %% [markdown]
# Create a string into an iterator and print each character using next().

# %%
text="Hello"
text_iter=iter(text)

# %%
print(next(text_iter))
print(next(text_iter))
print(next(text_iter))
print(next(text_iter))
print(next(text_iter))
# Out:
# H
# e
# l
# l
# o

# %% [markdown]
# Create an iterator and print by using for loop?

# %%
data=[1,2,3,4,5,6]
iterator=iter(data)

for item in iterator:
  print(item)

for char in letter:
  print(char)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# How to you use a for loop to iterate over an iterator.

# %%
letter= iter(["A", "B","C","D","E","F"])
for char in letter:
  print(char)
# Out:
# A
# B
# C
# D
# E
# F

# %% [markdown]
# How do you use iter() and next() to iterate through a range of numbers?

# %%
number_iter=iter(range(10))

# %%
print(next(number_iter))
print(next(number_iter))
print(next(number_iter))
# Out:
# 0
# 1
# 2

# %%
print(range(10))
# Out:
# range(0, 10)

# %% [markdown]
# Manually iterate through a tuple using an iterator and a while loop?

# %%
fruits=("Apple","Banana","Cherry")
fruit_iter=iter(fruits)

while True:
  try:
    print(next(fruit_iter))
  except StopIteration:
    break
# Out:
# Apple
# Banana
# Cherry

# %%
name=("Aryan","Madhu","Deepa")
name_iter=iter(name)

while True:
  try:
    print(next(name_iter))

  except StopIteration:
    break
# Out:
# Aryan
# Madhu
# Deepa
