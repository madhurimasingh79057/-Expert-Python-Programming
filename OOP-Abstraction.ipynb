# %% [markdown]
# Import ABC from abc
#
# abc - Stand for Abstract Base Classes

# %%
from abc import ABC, abstractmethod

# %%
class Animal(ABC):
  @abstractmethod
  def make_sound(self):
    pass


class Lion(Animal):
  def make_sound(self):
    print("Roar")


class Bull(Animal):
  def make_sound(self):
    print("Bellow")


lion=Lion()
bull=Bull()

# %%
lion.make_sound()
# Out:
# Roar

# %%
bull.make_sound()
# Out:
# Bellow

# %%
class Car(ABC):
  @abstractmethod
  def mileage(self):
    pass
  def color(self):
    print("Grey")

class BMW(Car):
  def mileage(self):
    print("The Mileage is 15 km/h")

class Audi(Car):
  def mileage(self):
    print("The mileage is 20 km/h")


B=BMW()
A=Audi()

# %%
A.mileage()
# Out:
# The mileage is 20 km/h

# %%
A.color()
# Out:
# Grey

# %%
B.mileage()
# Out:
# The Mileage is 15 km/h

# %%
B.color()
# Out:
# Grey

# %%
class Vehicle(ABC):
  @abstractmethod
  def max_speed(self):
    pass


class Bus(Vehicle):
  def max_speed(self):
    print("300 km/h")


class Truck(Vehicle):
  def max_speed(self):
    print("250 km/h")


b=Bus()
t=Truck()
b.max_speed()
# Out:
# 300 km/h

# %%
t.max_speed()
# Out:
# 250 km/h

# %%
class BankApp(ABC):
  def database(self):
    print("Connected to database")


@abstractmethod
def security(self):
  pass


class MobileApp(BankApp):
  def mobile_login(self):
    print("Login into mobile")


  def security(self):
    print("Mobile security")

# %%
m=MobileApp()
m.database()
m.mobile_login()
m.security()
# Out:
# Connected to database
# Login into mobile
# Mobile security

# %%
class Shape(ABC):
  @abstractmethod
  def area(self):
    pass


class Cricle(Shape):
  def __init__(self,radius):
    self.radius=radius

  def area(self):
    return 3.17 * self.radius * self.radius

# %%
C=Cricle(7)
print(C.area())
# Out:
# 155.32999999999998
